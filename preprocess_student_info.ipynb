# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
path = '/content/drive/My Drive/data/hcmut/full_data.csv'
df = pd.read_csv(path)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,3,8,9,27,28,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['NAMHOC', 'TENHK', 'NHHK', 'F_MAMH', 'F_TENMHVN', 'F_DVHT',
#        'F_PHTRAMKT', 'F_PHTRAMTH', 'F_MANH', 'F_TO', 'STT', 'F_MAKH',
#        'F_TENLOP', 'F_KHOI', 'F_MANG', 'F_TENNGVN', 'MASV1', 'KT', 'TILEKT',
#        'BT', 'TILEBT', 'BTLDA', 'TILEBTLDA', 'TN', 'TILETN', 'THI', 'TILETHI',
#        'TKET', 'F_DIEM1', 'F_DIEM2', 'F_DIEM10', 'GHICHU', 'T'],
#       dtype='object')

# %%
list_st_info = ['MASV1', 'F_MAKH', 'F_TENLOP', 'F_KHOI', 'F_MANG', 'F_TENNGVN']
list_mh_info = ['F_MAMH', 'F_TENMHVN', 'F_DVHT']

# %%
df_st_info = df[list_st_info]
df_mh_info = df[list_mh_info]

# %%
df_st_info.drop_duplicates(inplace=True)
df_mh_info.drop_duplicates(inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_st_info.to_csv("student_info.csv", index=False)
df_mh_info.to_csv("monhoc_info.csv", index=False)

# %%
# !cp student_info.csv /content/drive/My\ Drive/data/hcmut/
# !cp monhoc_info.csv  /content/drive/My\ Drive/data/hcmut/
